# %%
import data_handler as dh
import pandas as pd
import matplotlib.pyplot as plt

# %%
spectra = dh.process_set('./data', True, True, ',')

# %%
processed_spectra=dh.to_dataframe(spectra)

# %%
transposed = processed_spectra.T
fig = plt.figure()
for column in transposed:
    transposed[column].plot()
    plt.savefig('./plots/' + column + '.pdf')
    plt.clf()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-db1438a6b1da> in <module>()
#       3 for column in transposed:
#       4     transposed[column].plot()
# ----> 5     plt.savefig('./plots/' + column + '.pdf')
#       6     plt.clf()
#
# /usr/local/lib/python3.4/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     575 def savefig(*args, **kwargs):
#     576     fig = gcf()
# --> 577     res = fig.savefig(*args, **kwargs)
#     578     draw()   # need this if 'transparent=True' to reset colors
#     579     return res
#
# /usr/local/lib/python3.4/site-packages/matplotlib/figure.py in savefig(self, *args, **kwargs)
#    1468             self.set_frameon(frameon)
#    1469
# -> 1470         self.canvas.print_figure(*args, **kwargs)
#    1471
#    1472         if frameon:
#
# ...

# %%
plt.close()

# %%
unnormalized = dh.process_set('./data', False, True, ',')
processed_unnormalized = dh.to_dataframe(unnormalized)
processed_unnormalized
# Out:
#                6269.647041  6269.897041  6270.147041  6270.397041  \
# tj300033.fits     0.982924     0.971895     0.970630     0.986146
# vj080026.fits     0.987614     0.981417     0.979802     0.979268
# la040025.fits     0.997626     0.993757     0.992666     0.996915
# ub200035.fits     0.984453     0.989074     0.989760     0.992295
# vc170037.fits     0.993883     0.992887     0.992239     0.998015
# ui260022.fits     0.978287     0.994481     0.990379     0.989672
# mj180032.fits     1.002151     1.001754     1.001967     1.002895
# mj180033.fits     0.996567     0.996547     1.000570     1.002148
# ng290046.fits     0.994108     0.995744     0.997191     0.991490
# vh130095.fits     0.998131     0.999862     0.996407     0.996364
# vh200031.fits     1.008795     1.009481     1.000173     0.987339
# vh200041.fits     1.003429     1.001292     0.997759     0.998191
# vh210049.fits     1.004689     1.002234     0.998620     0.993528
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
X = [fits['data'] for fits in name]
y = [fits['class'] for fits in name]
forest = RandomForestClassifier(n_estimators=2000, criterion='entropy', oob_score=True, n_jobs=-1, verbose=100)
forest2 = forest.fit(X, y)
# Out:
# building tree 1 of 500
# building tree 1 of 500
# building tree 1 of 500
# building tree 1 of 500
# building tree 2 of 500
# building tree 2 of 500
# building tree 2 of 500
# building tree 2 of 500
# building tree 3 of 500
# building tree 3 of 500
# building tree 3 of 500
# building tree 3 of 500
# building tree 4 of 500
# building tree 4 of 500
# building tree 4 of 500
# building tree 5 of 500
# building tree 4 of 500
# building tree 5 of 500
# building tree 5 of 500
# building tree 6 of 500
# building tree 5 of 500
# building tree 6 of 500
# building tree 6 of 500
# building tree 7 of 500
# building tree 6 of 500
# building tree 7 of 500
# building tree 7 of 500
# building tree 8 of 500
# building tree 7 of 500
# building tree 8 of 500
# building tree 8 of 500
# building tree 9 of 500
# building tree 8 of 500
# building tree 9 of 500
# building tree 9 of 500
# building tree 10 of 500
# building tree 9 of 500
# building tree 11 of 500
# building tree 10 of 500
# ...

# %%
forest2.oob_score
# Out:
# True

# %%
forest.oob_score
# Out:
# True

# %%
forest
# Out:
# RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='entropy', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_density=None, min_samples_leaf=1,
#             min_samples_split=2, n_estimators=2000, n_jobs=-1,
#             oob_score=True, random_state=None, verbose=100)

# %%
forest.feature_importances_
# Out:
# array([  4.32020658e-05,   7.72728552e-05,   1.02868713e-04, ...,
#          2.19962246e-05,   4.35701010e-05,   5.19334625e-05])

# %%
forest.oob_score_
# Out:
# 0.9855618330194601
